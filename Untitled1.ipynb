# %%
# !pip install qiskit
# !pip install qiskit-aer
# !pip install qiskit-ignis
# !pip install qiskit-terra
# Out:
# Requirement already satisfied: qiskit in c:\users\dell\anaconda3\lib\site-packages (0.45.0)
# Requirement already satisfied: qiskit-terra==0.45.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit) (0.45.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (0.13.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (1.24.3)
# Requirement already satisfied: ply>=3.10 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (5.9.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (1.10.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (1.11.1)
# Requirement already satisfied: dill>=0.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (0.3.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit) (5.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.0->qiskit) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.0->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dell\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra==0.45.0->qiskit) (1.3.0)
# Requirement already satisfied: qiskit-aer in c:\users\dell\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: qiskit>=0.44.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-aer) (0.45.0)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-aer) (1.24.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-aer) (1.10.1)
# Requirement already satisfied: qiskit-terra==0.45.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit>=0.44.0->qiskit-aer) (0.45.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (0.13.2)
# Requirement already satisfied: ply>=3.10 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (5.9.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (1.11.1)
# Requirement already satisfied: dill>=0.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (0.3.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (5.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dell\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra==0.45.0->qiskit>=0.44.0->qiskit-aer) (1.3.0)
# Requirement already satisfied: qiskit-ignis in c:\users\dell\anaconda3\lib\site-packages (0.7.1)
# Requirement already satisfied: numpy>=1.13 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-ignis) (1.24.3)
# Requirement already satisfied: qiskit-terra>=0.15.1 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-ignis) (0.45.0)
# Requirement already satisfied: retworkx>=0.8.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-ignis) (0.13.2)
# Requirement already satisfied: scipy!=0.19.1,>=0.19 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-ignis) (1.10.1)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-ignis) (68.0.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra>=0.15.1->qiskit-ignis) (0.13.2)
# Requirement already satisfied: ply>=3.10 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra>=0.15.1->qiskit-ignis) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra>=0.15.1->qiskit-ignis) (5.9.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra>=0.15.1->qiskit-ignis) (1.11.1)
# Requirement already satisfied: dill>=0.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra>=0.15.1->qiskit-ignis) (0.3.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra>=0.15.1->qiskit-ignis) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra>=0.15.1->qiskit-ignis) (5.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.15.1->qiskit-ignis) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra>=0.15.1->qiskit-ignis) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dell\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.15.1->qiskit-ignis) (1.3.0)
# Requirement already satisfied: qiskit-terra in c:\users\dell\anaconda3\lib\site-packages (0.45.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (0.13.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (1.24.3)
# Requirement already satisfied: ply>=3.10 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (5.9.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (1.10.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (1.11.1)
# Requirement already satisfied: dill>=0.3 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (0.3.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from qiskit-terra) (5.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dell\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra) (1.3.0)

# %%
from qiskit import *
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise.errors import depolarizing_error, thermal_relaxation_error
from qiskit.ignis.verification.topological_codes import RepetitionCode
from qiskit.ignis.verification.topological_codes import GraphDecoder

# Define the repetition code
code = RepetitionCode(3, 1)  # Repetition code with 3 qubits and 1 logical qubit

def make_noise(p_cx=0, T1T2Tm=(1, 1, 0)):
    '''
    Returns a noise model specified by the inputs
    - p_cx: probability of depolarizing noise on each
            qubit during a cx
    - T1T2Tm: tuple with (T1, T2, Tm), the T1 and T2 times
          and the measurement time
    '''

    noise_model = NoiseModel()

    # Depolarizing error for CX gates
    error_cx = depolarizing_error(p_cx, 1)
    error_cx = error_cx.tensor(error_cx)
    noise_model.add_all_qubit_quantum_error(error_cx, ["cx"])

    # Thermal error for measurement
    (T1, T2, Tm) = T1T2Tm
    error_meas = thermal_relaxation_error(T1, T2, Tm)
    noise_model.add_all_qubit_quantum_error(error_meas, "measure")

    return noise_model

def get_results(code, noise_model, shots=8192):
    circuits = code.get_circuit_list()

    job = execute(circuits, Aer.get_backend('qasm_simulator'), noise_model=noise_model, shots=shots)

    raw_results = {}
    for log in ['0', '1']:
        raw_results[log] = job.result().get_counts(log)

    results = code.process_results(raw_results)

    return results

# Define the noise model with a 1% probability of depolarizing error on CX gates
noise_model = make_noise(p_cx=0.01)

results = get_results(code, noise_model)

# Initialize the decoder
decoder = GraphDecoder(code)

# Get logical error probabilities
logical_prob = decoder.get_logical_prob(results)

for log in logical_prob:
    print(f'\nLogical error probability for state {log}: {logical_prob[log]}')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_159108\792539067.py:4: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.verification.topological_codes import RepetitionCode
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 49
#      46 # Define the noise model with a 1% probability of depolarizing error on CX gates
#      47 noise_model = make_noise(p_cx=0.01)
# ---> 49 results = get_results(code, noise_model)
#      51 # Initialize the decoder
#      52 decoder = GraphDecoder(code)
#
# Cell In[2], line 36, in get_results(code, noise_model, shots)
#      33 def get_results(code, noise_model, shots=8192):
#      34     circuits = code.get_circuit_list()
# ---> 36     job = execute(circuits, Aer.get_backend('qasm_simulator'), noise_model=noise_model, shots=shots)
#      38     raw_results = {}
#      39     for log in ['0', '1']:
#
# File ~\anaconda3\Lib\site-packages\qiskit\execute_function.py:286, in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, shots, memory, seed_simulator, default_qubit_los, default_meas_los, qubit_lo_range, meas_lo_range, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     283     experiments = pass_manager.run(experiments)
#     284 else:
#     285     # transpiling the circuits using given transpile options
# --> 286     experiments = transpile(
#     287         experiments,
#     288         basis_gates=basis_gates,
#     289         coupling_map=coupling_map,
#     290         backend_properties=backend_properties,
#     291         initial_layout=initial_layout,
#     292         seed_transpiler=seed_transpiler,
#     293         optimization_level=optimization_level,
#     294         backend=backend,
#     295     )
#     297 if schedule_circuit:
#     298     experiments = schedule(
#     299         circuits=experiments,
#     300         backend=backend,
#    (...)
#     303         method=scheduling_method,
#     304     )
#
# File ~\anaconda3\Lib\site-packages\qiskit\compiler\transpiler.py:428, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     400         instruction_durations = _parse_instruction_durations(
#     401             backend, instruction_durations, dt, circuits[0]
#     402         )
#     404 pm = generate_preset_pass_manager(
#     405     optimization_level,
#     406     backend=backend,
#    (...)
#     426     _skip_target=_skip_target,
#     427 )
# --> 428 out_circuits = pm.run(circuits, callback=callback)
#     429 for name, circ in zip(output_name, out_circuits):
#     430     circ.name = name
#
# File ~\anaconda3\Lib\site-packages\qiskit\transpiler\passmanager.py:532, in StagedPassManager.run(self, circuits, output_name, callback)
#     525 def run(
#     526     self,
#     527     circuits: _CircuitsT,
#     528     output_name: str | None = None,
#     529     callback: Callable | None = None,
#     530 ) -> _CircuitsT:
#     531     self._update_passmanager()
# --> 532     return super().run(circuits, output_name, callback)
#
# File ~\anaconda3\Lib\site-packages\qiskit\transpiler\passmanager.py:551, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     548 @wraps(meth)
#     549 def wrapper(*meth_args, **meth_kwargs):
#     550     try:
# --> 551         return meth(*meth_args, **meth_kwargs)
#     552     except PassManagerError as ex:
#     553         raise TranspilerError(ex.message) from ex
#
# File ~\anaconda3\Lib\site-packages\qiskit\transpiler\passmanager.py:291, in PassManager.run(self, circuits, output_name, callback)
#     288 if callback is not None:
#     289     callback = _legacy_style_callback(callback)
# --> 291 return super().run(
#     292     in_programs=circuits,
#     293     callback=callback,
#     294     output_name=output_name,
#     295 )
#
# File ~\anaconda3\Lib\site-packages\qiskit\passmanager\passmanager.py:242, in BasePassManager.run(***failed resolving arguments***)
#     233 del kwargs
#     235 # Pass manager may contain callable and we need to serialize through dill rather than pickle.
#     236 # See https://github.com/Qiskit/qiskit-terra/pull/3290
#     237 # Note that serialized object is deserialized as a different object.
#     238 # Thus, we can resue the same manager without state collision, without building it per thread.
#     239 return parallel_map(
#     240     _run_workflow_in_new_process,
#     241     values=in_programs,
# --> 242     task_kwargs={"pass_manager_bin": dill.dumps(self)},
#     243 )
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:263, in dumps(obj, protocol, byref, fmode, recurse, **kwds)
#     239 """
#     240 Pickle an object to a string.
#     241
#    (...)
#     260 Default values for keyword arguments can be set in :mod:`dill.settings`.
#     261 """
#     262 file = StringIO()
# --> 263 dump(obj, file, protocol, byref, fmode, recurse, **kwds)#, strictio)
#     264 return file.getvalue()
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:235, in dump(obj, file, protocol, byref, fmode, recurse, **kwds)
#     233 _kwds = kwds.copy()
#     234 _kwds.update(dict(byref=byref, fmode=fmode, recurse=recurse))
# --> 235 Pickler(file, protocol, **_kwds).dump(obj)
#     236 return
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:394, in Pickler.dump(self, obj)
#     392 def dump(self, obj): #NOTE: if settings change, need to update attributes
#     393     logger.trace_setup(self)
# --> 394     StockPickler.dump(self, obj)
#
# File ~\anaconda3\Lib\pickle.py:487, in _Pickler.dump(self, obj)
#     485 if self.proto >= 4:
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#     489 self.framer.end_framing()
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~\anaconda3\Lib\pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:1186, in save_module_dict(pickler, obj)
#    1183     if is_dill(pickler, child=False) and pickler._session:
#    1184         # we only care about session the first pass thru
#    1185         pickler._first_pass = False
# -> 1186     StockPickler.save_dict(pickler, obj)
#    1187     logger.trace(pickler, "# D2")
#    1188 return
#
# File ~\anaconda3\Lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~\anaconda3\Lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File ~\anaconda3\Lib\pickle.py:956, in _Pickler._batch_appends(self, items)
#     954     write(MARK)
#     955     for x in tmp:
# --> 956         save(x)
#     957     write(APPENDS)
#     958 elif n:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:1186, in save_module_dict(pickler, obj)
#    1183     if is_dill(pickler, child=False) and pickler._session:
#    1184         # we only care about session the first pass thru
#    1185         pickler._first_pass = False
# -> 1186     StockPickler.save_dict(pickler, obj)
#    1187     logger.trace(pickler, "# D2")
#    1188 return
#
# File ~\anaconda3\Lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~\anaconda3\Lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File ~\anaconda3\Lib\pickle.py:956, in _Pickler._batch_appends(self, items)
#     954     write(MARK)
#     955     for x in tmp:
# --> 956         save(x)
#     957     write(APPENDS)
#     958 elif n:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~\anaconda3\Lib\pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:1186, in save_module_dict(pickler, obj)
#    1183     if is_dill(pickler, child=False) and pickler._session:
#    1184         # we only care about session the first pass thru
#    1185         pickler._first_pass = False
# -> 1186     StockPickler.save_dict(pickler, obj)
#    1187     logger.trace(pickler, "# D2")
#    1188 return
#
# File ~\anaconda3\Lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~\anaconda3\Lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~\anaconda3\Lib\pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:1186, in save_module_dict(pickler, obj)
#    1183     if is_dill(pickler, child=False) and pickler._session:
#    1184         # we only care about session the first pass thru
#    1185         pickler._first_pass = False
# -> 1186     StockPickler.save_dict(pickler, obj)
#    1187     logger.trace(pickler, "# D2")
#    1188 return
#
# File ~\anaconda3\Lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~\anaconda3\Lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:1186, in save_module_dict(pickler, obj)
#    1183     if is_dill(pickler, child=False) and pickler._session:
#    1184         # we only care about session the first pass thru
#    1185         pickler._first_pass = False
# -> 1186     StockPickler.save_dict(pickler, obj)
#    1187     logger.trace(pickler, "# D2")
#    1188 return
#
# File ~\anaconda3\Lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~\anaconda3\Lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:1698, in save_type(pickler, obj, postproc_list)
#    1696             postproc_list = []
#    1697         postproc_list.append((setattr, (obj, '__qualname__', obj_name)))
# -> 1698     _save_with_postproc(pickler, (_create_type, (
#    1699         type(obj), obj.__name__, obj.__bases__, _dict
#    1700     )), obj=obj, postproc_list=postproc_list)
#    1701     logger.trace(pickler, "# T2")
#    1702 else:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:1070, in _save_with_postproc(pickler, reduction, is_pickler_dill, obj, postproc_list)
#    1067     pickler._postproc[id(obj)] = postproc_list
#    1069 # TODO: Use state_setter in Python 3.8 to allow for faster cPickle implementations
# -> 1070 pickler.save_reduce(*reduction, obj=obj)
#    1072 if is_pickler_dill:
#    1073     # pickler.x -= 1
#    1074     # print(pickler.x*' ', 'pop', obj, id(obj))
#    1075     postproc = pickler._postproc.pop(id(obj))
#
# File ~\anaconda3\Lib\pickle.py:692, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690 else:
#     691     save(func)
# --> 692     save(args)
#     693     write(REDUCE)
#     695 if obj is not None:
#     696     # If the object is already in the memo, this means it is
#     697     # recursive. In this case, throw away everything we put on the
#     698     # stack, and fetch the object back from the memo.
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\pickle.py:902, in _Pickler.save_tuple(self, obj)
#     900 write(MARK)
#     901 for element in obj:
# --> 902     save(element)
#     904 if id(obj) in memo:
#     905     # Subtle.  d was not in memo when we entered save_tuple(), so
#     906     # the process of saving the tuple's elements must have saved
#    (...)
#     910     # could have been done in the "for element" loop instead, but
#     911     # recursive tuples are a rare thing.
#     912     get = self.get(memo[id(obj)][0])
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:1186, in save_module_dict(pickler, obj)
#    1183     if is_dill(pickler, child=False) and pickler._session:
#    1184         # we only care about session the first pass thru
#    1185         pickler._first_pass = False
# -> 1186     StockPickler.save_dict(pickler, obj)
#    1187     logger.trace(pickler, "# D2")
#    1188 return
#
# File ~\anaconda3\Lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File ~\anaconda3\Lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:388, in Pickler.save(self, obj, save_persistent_id)
#     386     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     387     raise PicklingError(msg)
# --> 388 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\anaconda3\Lib\pickle.py:578, in _Pickler.save(self, obj, save_persistent_id)
#     576 reduce = getattr(obj, "__reduce_ex__", None)
#     577 if reduce is not None:
# --> 578     rv = reduce(self.proto)
#     579 else:
#     580     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle '_abc._abc_data' object
